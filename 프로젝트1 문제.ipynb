# %% [markdown]
# # 프로젝트 수행 가이드
#
# + ipynb 파일이름을 `프로젝트1_본인이름`으로 변경
# + 아래의 문제를 해결하기 위한 Python 코드를 작성
# + 별도로 안내된 방법에 따라 결과물 제출

# %% [markdown]
# **변수 설명**
#
# 프로젝트1에서 활용하는 데이터는 2010년 1월부터 2020년 5월까지의 데이터에 해당하는 총 125개의 엑셀파일입니다. 이 데이터는 한국관광공사에서 공유하는 "월별 외래객 입국 - 목적별/국적별" 통계 데이터입니다.
#
# * 국적 : 한국에 입국한 외국인의 국적
# * 관광 : 사증면제 + 관광통과 + 단기종합 + 관광취업 + 관광상륙 + 의료관광
# * 상용 : 단기상용 + 상사주재 + 기업투자 + 무역경영
# * 공용 : 공무 + 협정
# * 유학연수 : 유학 + 일반연수
# * 기타 : 나머지 항목 + 승무원

# %% [markdown]
# # 프로젝트1 : 중국인 관광객의 변화 추이 분석

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.rc('font', family='Malgun Gothic')

# %% [markdown]
# ## 문제1
# ### kto_201001.xlsx 파일을 불러오세요.
#
# 1. kto_201001.xlsx의 `1행`을 열로 설정하세요.
# 2. kto_201001.xlsx에서 `A:G열`까지만 가져오세요.
# 3. kto_201001.xlsx의 `가장 아래에 있는 행 4개`를 지우세요.
# 4. 1~3번까지 데이터 전처리가 끝나면 가공된 데이터프레임을 `sample` 이라는 변수에 할당하세요.

# %%
# Out:
#          국적      관광     상용   공용  유학/연수     기타       계
# 0      아시아주  329131  18238  421   4339  80916  433045
# 1        일본  202825   1750   89    549   3971  209184
# 2        대만   35788     41   17     37    516   36399
# 3        홍콩   13874     55    0     21    595   14545
# 4       마카오     554      0    0      0      0     554
# ..      ...     ...    ...  ...    ...    ...     ...
# 62  아프리카 기타     349    594   25     86    296    1350
# 63     기타대륙      10      3    0      0      0      13
# 64     국적미상      10      3    0      0      0      13
# 65     교포소계       0      0    0      0  22537   22537
# 66       교포       0      0    0      0  22537   22537
#
# [67 rows x 7 columns]

# %% [markdown]
# ## 문제2
# ### kto201001.xlsx ~ kto202005.xlsx까지 125개의 엑셀파일을 불러오세요.
# 1. 불러온 데이터프레임에서 `1행`을 열로 설정하세요.
# 2. 불러온 데이터프레임에서 `A:G열`까지만 가져오세요.
# 3. 불러온 데이터프레임의 `가장 아래에 있는 행 4개`를 지우세요.
# 4. 불러온 데이터프레임에 `year` 열을 생성하세요.
# 5. 불러온 데이터프레임에 `month` 열을 생성하세요.
# 6. 불러온 데이터프레임에 `date` 열을 생성하세요. (년-월)
# 7. 불러온 데이터프레임에 `관광객비율(%)` 열을 생성하세요. (`관광`열에서 `계`열을 나눈 후 100을 곱한 값)
# 8. 불러온 데이터프레임에 `전체비율(%)` 열을 생성하세요. (`관광`열에서 `관광`열의 `합`을 나눈 후 100을 곱한 값)
# 9. 불러온 125개의 데이터프레임을 하나의 데이터프레임으로 만든후 index를 초기화 한 후 `df` 라는 변수에 할당하세요.

# %%
# Out:
#            국적      관광     상용   공용  유학/연수     기타       계    관광객비율(%)  \
# 0        아시아주  329131  18238  421   4339  80916  433045   76.003880
# 1          일본  202825   1750   89    549   3971  209184   96.960093
# 2          대만   35788     41   17     37    516   36399   98.321382
# 3          홍콩   13874     55    0     21    595   14545   95.386731
# 4         마카오     554      0    0      0      0     554  100.000000
# ...       ...     ...    ...  ...    ...    ...     ...         ...
# 8370  아프리카 기타       3      1    3      6    118     131    2.290076
# 8371     기타대륙       1      0    0      0      3       4   25.000000
# 8372     국적미상       1      0    0      0      3       4   25.000000
# 8373     교포소계       0      0    0      0    790     790    0.000000
# 8374       교포       0      0    0      0    790     790    0.000000
#
#         전체비율(%)  year month     date
# 0     41.057413  2010    01  2010-01
# 1     25.301384  2010    01  2010-01
# ...

# %% [markdown]
# ## 문제3
# 1. 데이터프레임 df에서 `국적` 열에 있는 값 중 `구주, 미주, 대양주, 아시아주, 아프리카주`인 값을 가진 행을 모두 삭제하세요.

# %%
# Out:
#            국적      관광    상용  공용  유학/연수    기타       계    관광객비율(%)    전체비율(%)  \
# 1          일본  202825  1750  89    549  3971  209184   96.960093  25.301384
# 2          대만   35788    41  17     37   516   36399   98.321382   4.464370
# 3          홍콩   13874    55   0     21   595   14545   95.386731   1.730711
# 4         마카오     554     0   0      0     0     554  100.000000   0.069109
# 5          태국   13374    39  13     53  4335   17814   75.075783   1.668338
# ...       ...     ...   ...  ..    ...   ...     ...         ...        ...
# 8370  아프리카 기타       3     1   3      6   118     131    2.290076   0.024546
# 8371     기타대륙       1     0   0      0     3       4   25.000000   0.008182
# 8372     국적미상       1     0   0      0     3       4   25.000000   0.008182
# 8373     교포소계       0     0   0      0   790     790    0.000000   0.000000
# 8374       교포       0     0   0      0   790     790    0.000000   0.000000
#
#       year month     date
# 1     2010    01  2010-01
# ...

# %% [markdown]
# ## 문제4
# 1. 데이터프레임 df에서 `국적별 관광 목적으로 온 외국인 관광객의 평균값`을 집계하고 `country` 라는 이름의 변수에 할당하세요.
# 2. 데이터프레임 country를 활용하여 x축은 `국적`, y축은 `관광` 목적으로 온 외국인 관광객의 평균 값을 보여주는 `막대 그래프` 만들어 출력하세요.

# %%
# Out:
# 국적
# GCC       1557.928
# 교포           0.000
# 교포소계         0.000
# 구주 기타     1740.192
# 국적미상        22.968
#            ...
# 폴란드        802.224
# 프랑스       5170.456
# 핀란드        607.848
# 필리핀      12863.720
# 홍콩       40046.944
# Name: 관광, Length: 62, dtype: float64

# %%
# Out:
# <AxesSubplot:xlabel='국적'>

# %% [markdown]
# ## 문제5
# 1. 데이터프레임 df에서 국적이 `중국`인 행만 추출하여 `china` 라는 변수에 할당하세요.
# 2. 데이터프레임 china가 `결측치`가 있는지 확인하세요.

# %%
# Out:
#       국적      관광     상용   공용  유학/연수     기타       계   관광객비율(%)    전체비율(%)  \
# 18    중국   40425  11930   55   2751  36091   91252  44.300399   5.042812
# 85    중국   60590   7907   68  29546  42460  140571  43.102774   6.784615
# 152   중국   50330  13549  174  14924  62480  141457  35.579717   4.613689
# 219   중국   84252  13306  212   2199  47711  147680  57.050379   7.753770
# 286   중국   89056  12325  360   2931  49394  154066  57.803798   8.476035
# ...   ..     ...    ...  ...    ...    ...     ...        ...        ...
# 8058  중국  393336   2813   99  10433  75000  481681  81.659023  19.084772
# 8125  중국   49520    715   11  20753  33087  104086  47.576043   4.912932
# 8192  중국    5040    115    2   7388   4050   16595  30.370594   8.000762
# 8259  중국     522     71    0   1112   2230    3935  13.265565   5.082765
# 8326  중국     179     70    2   1189   3684    5124   3.493365   1.464572
#
#       year month     date
# 18    2010    01  2010-01
# 85    2010    02  2010-02
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125 entries, 18 to 8326
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국적        125 non-null    object
#  1   관광        125 non-null    int64
#  2   상용        125 non-null    int64
#  3   공용        125 non-null    int64
#  4   유학/연수     125 non-null    int64
#  5   기타        125 non-null    int64
#  6   계         125 non-null    int64
#  7   관광객비율(%)  125 non-null    float64
#  8   전체비율(%)   125 non-null    float64
#  9   year      125 non-null    object
#  10  month     125 non-null    object
#  11  date      125 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 10.7+ KB

# %% [markdown]
# ## 문제6
# 1. 데이터프레임 china에서 행은 `year`열, 열은 `month`열, 값은 `관광`열의 값을 가지는 `피벗 테이블`을 생성하고 `china_pivot` 변수에 할당하세요.
# 2. 데이터프레임 china_pivot을 활용해서 `heatmap`을 그리세요.

# %%
# Out:
# month        01        02        03        04        05        06        07  \
# year
# 2010    40425.0   60590.0   50330.0   84252.0   89056.0   87080.0  122432.0
# 2011    55070.0   53863.0   72003.0   86397.0   85668.0  108060.0  170524.0
# 2012   106606.0   74895.0  110965.0  166843.0  154841.0  179074.0  258907.0
# 2013   148118.0  169395.0  182850.0  250549.0  196306.0  280319.0  417991.0
# 2014   230706.0  219533.0  313400.0  429419.0  410971.0  429991.0  540683.0
# 2015   327225.0  413096.0  386386.0  536428.0  517154.0  223101.0  172075.0
# 2016   456636.0  424232.0  500018.0  601460.0  614636.0  671493.0  823016.0
# 2017   489256.0  458952.0  263788.0  158784.0  172527.0  181507.0  207099.0
# 2018   236825.0  237075.0  281020.0  283533.0  284317.0  303405.0  332657.0
# 2019   320113.0  324291.0  369165.0  410542.0  413949.0  395196.0  439699.0
# 2020   393336.0   49520.0    5040.0     522.0     179.0       NaN       NaN
#
# ...

# %%
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>
